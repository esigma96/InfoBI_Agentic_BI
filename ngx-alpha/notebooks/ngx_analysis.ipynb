# %%
import sys
import os
sys.path.append(os.path.abspath(".."))
from src.preprocess import load_data
from src.features import create_features
from src.train_model import train
from src.predict import generate_predictions

df = load_data()
df = create_features(df)

model, acc = train(df)

df = generate_predictions(model, df)

df.to_csv("outputs/predictions.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from src.preprocess import load_data
#       2 from src.features import create_features
#       3 from src.train_model import train
#       4 from src.predict import generate_predictions
#
# ModuleNotFoundError: No module named 'src'
